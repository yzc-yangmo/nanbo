# %%
from bs4 import BeautifulSoup

# %%
from datetime import datetime
current_time = datetime.now().strftime('%Y%m%d%H%M%S')
current_time
# Out:
# '20240504130920'

# %%
import requests

cookies = {
    'JSESSIONID': '2F01DDC8D7AAEE826A4CCC5590B1212C',
    'UM_distinctid': '18b7a3285177ff-0d931be07d2d72-26031151-1bcab9-18b7a328518125d',
    'CNZZDATA1281245212': '160630283-1698562213-https%253A%252F%252Fwww.njmuseum.com%252F%7C1698566518',
    'acw_sc__v2': '6629d47de9b0ed026cf43480748aae74773a45c0',
    'acw_tc': '76b20ff217140188914591816e3831fb56dac6c607d5293492c1f41e0a0998',
    'tfstk': 'f-XIYYm5f20I1pj6rBEwCe1-Y1J7bww4e0tRmgHE2ppp28_R-6kP2vyWyZbMTB-e8YMR7FWeapdrFUQV4brHz675NFIAY97Ux3QG0iLp8H8P5UQP068HazmhsZSxL9PHUY9HELU4u-y2YMvkeTDTWh0HX3xQUvdpJPUHpga4u-yN2CaUJr5P9jXff3Y9vHKJ9lO9qFnpeed-WfKvWUpJeaL9BHxSevLJ9CLtpX32Vu8CAzlu5s_YrBsp5xsGCHEvo-YteN6wvB6fYFZabOtBOEdsyrnVpNSRL9Aglqplbs_5waVqspsR9pKVxJM6HMCNFhWz4bTd-OsOBCiq3L1dR_dc1-cD9QTC69ds2YIMF1dANwaIteCF5Ix960wDbZ8Ox9C_qVIdue9pXCyYcGdR_9AcLPHBHsjeL_QugfvC26p14pD2lgloNcOmehT4flGoadWbjhFrBm-D9hxBClZsRddpjhT4flGuXBKMbqr_fj7F.',
}

headers = {
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    'Accept-Language': 'zh-CN,zh;q=0.9,en;q=0.8,en-GB;q=0.7,en-US;q=0.6',
    'Cache-Control': 'max-age=0',
    'Connection': 'keep-alive',
    'Content-Type': 'application/x-www-form-urlencoded',
    # 'Cookie': 'JSESSIONID=2F01DDC8D7AAEE826A4CCC5590B1212C; UM_distinctid=18b7a3285177ff-0d931be07d2d72-26031151-1bcab9-18b7a328518125d; CNZZDATA1281245212=160630283-1698562213-https%253A%252F%252Fwww.njmuseum.com%252F%7C1698566518; acw_sc__v2=6629d47de9b0ed026cf43480748aae74773a45c0; acw_tc=76b20ff217140188914591816e3831fb56dac6c607d5293492c1f41e0a0998; tfstk=f-XIYYm5f20I1pj6rBEwCe1-Y1J7bww4e0tRmgHE2ppp28_R-6kP2vyWyZbMTB-e8YMR7FWeapdrFUQV4brHz675NFIAY97Ux3QG0iLp8H8P5UQP068HazmhsZSxL9PHUY9HELU4u-y2YMvkeTDTWh0HX3xQUvdpJPUHpga4u-yN2CaUJr5P9jXff3Y9vHKJ9lO9qFnpeed-WfKvWUpJeaL9BHxSevLJ9CLtpX32Vu8CAzlu5s_YrBsp5xsGCHEvo-YteN6wvB6fYFZabOtBOEdsyrnVpNSRL9Aglqplbs_5waVqspsR9pKVxJM6HMCNFhWz4bTd-OsOBCiq3L1dR_dc1-cD9QTC69ds2YIMF1dANwaIteCF5Ix960wDbZ8Ox9C_qVIdue9pXCyYcGdR_9AcLPHBHsjeL_QugfvC26p14pD2lgloNcOmehT4flGoadWbjhFrBm-D9hxBClZsRddpjhT4flGuXBKMbqr_fj7F.',
    'DNT': '1',
    'Origin': 'https://ticket.wisdommuseum.cn',
    'Referer': 'https://ticket.wisdommuseum.cn/reservation/ticketOut/out/saveOrderPC.do',
    'Sec-Fetch-Dest': 'iframe',
    'Sec-Fetch-Mode': 'navigate',
    'Sec-Fetch-Site': 'same-origin',
    'Sec-Fetch-User': '?1',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36 Edg/124.0.0.0',
    'sec-ch-ua': '"Chromium";v="124", "Microsoft Edge";v="124", "Not-A.Brand";v="99"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
}

params = {
    'u_atoken': '348050237c3111f738bfea4530153bad',
    'u_asession': '01ZIVoi_IUPY8NRVWtGquZqmshiM8nMcO0TzoWeT9XQrFQWNUvkY8nB-H1sghYFkf7dlmHJsN3PcAI060GRB4YZGyPlBJUEqctiaTooWaXr7I',
    'u_asig': '059jrqqLJul3e-YEwQ0SnngbwKeu1OKqnq00mnyNkGThfYmeM6kfLo6F3tTdc9saSx86rSz_ph9bwBqLc7oOe3u4e2Hbi0-aaVV64mXB6JxuUvhezNcVnV1s0HfYhB69wqDomFMm3l8G5GcldeWqS-dyeBnvEjRXN5SnC8Ho6XPQ1g2QMxYs6lyXb1lFWKql564jlh48G8VsRBbi_vuRkfxEBkyzE1rW3hMFSGELN-yWxLiWHHhmVMIAVJJWGyCPooEAeTo2P-VCQcuXKkhqE67Kv8bDXdKLZMZ06-FHBo4sSpzWsVy4MypSthgy7kVsVNbscs26JxJSqPcIcNZT6Uug',
    'u_aref': 'nGa3BMRU5L6Tg/UybfTpb64mBcA=',
}

data = {
    'token': '85be7df3-ae7f-4c1e-bd4c-ed4ffcca6d6f',
    'date': '2024-04-25',
    'ticketType': 'normal',
    'morAft': '下午',
    'deviceToken': 'v2:',
    'riskType': '1',
    'ids': '24389499',
}

response = requests.post(
    'https://ticket.wisdommuseum.cn/reservation/ticketOut/out/saveOrderPC.do',
    params=params,
    cookies=cookies,
    headers=headers,
    data=data,
)

# %%
old_r = response.text

# %%
new_r = response.text

# %%
BeautifulSoup(new_r, 'html.parser').prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <title>æ»å¨éªè¯é¡µé¢</title>
# <meta content="width=device-width, initial-scale=1.0" name="viewport">
# <style type="text/css">
#         html, body, div, span, p{
#             margin:0;
#             padding:0;
#             border:0;
#             outline:0;
#             font-size:100%;
#             vertical-align:baseline;
#             background:transparent;
#         }
#         body{
#             background: #fff;
#         }
#     </style>
# <script type="text/javascript">
#         if (window.console === undefined){
#             console = {};
#             console.log = function(){};
#         };
#
#         window._waf_is_mobile = false;
#
#         (function(a) {
# ...

# %%
str1 = 'v2:'
str2 = 'v2:'
str1 == str2
